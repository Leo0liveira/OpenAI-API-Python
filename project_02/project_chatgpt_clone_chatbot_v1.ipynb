# %% [markdown]
# # Project: Building a ChatGPT Clone From Scratch (ChatBot)

# %% [markdown]
# This project uses OpenAI API version 1 or later

# %%
pip install openai -q

# %% [markdown]
# ### OpenAI Authentication
# To use this notebook as shown, you must acquire an OpenAI API Key and set it as an environment variable or load it from a file.
#
# 1. Sign up at: https://platform.openai.com/signup
# 2. Generate a new API Key

# %%
import os
import openai

from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv(), override=True)
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
from openai import OpenAI

client = OpenAI()

q1 = 'What are the healthiest foods to eat every day?'
q2 = 'Make a recipe with those foods.'
q3 = 'What is the amount of kcal?'

# Q1
messages = [
    {'role': 'system', 'content': 'Answer as concisely as possible.'},
    {'role': 'user', 'content': q1}
]

response = client.chat.completions.create(
    model='gpt-5-nano',
    messages=messages,
    temperature=1
)

bot_response_1 = response.choices[0].message.content
print(bot_response_1)
print()
print('-' * 50)
print()

# Q2
messages = [
    {'role': 'system', 'content': 'Answer as concisely as possible.'},
    {'role': 'user', 'content': q1},
    {'role': 'assistant', 'content': bot_response_1},
    {'role': 'user', 'content': q2}
]

response = client.chat.completions.create(
    model='gpt-5-nano',
    messages=messages,
    temperature=1
)
bot_response_2 = response.choices[0].message.content
print(bot_response_2)

print()
print('-' * 50)
print()

# Q3
messages = [
    {'role': 'system', 'content': 'Answer as concisely as possible.'},
    {'role': 'user', 'content': q1},
    {'role': 'assistant', 'content': bot_response_1},
    {'role': 'user', 'content': q2},
    {'role': 'assistant', 'content': bot_response_2},
    {'role': 'user', 'content': q3},    
]

response = client.chat.completions.create(
    model='gpt-5-nano',
    messages=messages,
    temperature=1
)
bot_response_3 = response.choices[0].message.content
print(bot_response_3)
# Out:
# There isn’t a one-size-fits-all list, but these nutrient-dense foods are great to include daily:
#
# - Vegetables: aim for variety (spinach/kale, broccoli, peppers, carrots)
# - Fruits: berries, citrus, apples (1–2 servings)
# - Whole grains: oats, quinoa, brown rice, barley
# - Protein: beans/lentils, eggs, fish (fatty fish like salmon 2x/week), chicken, tofu/tempeh
# - Nuts and seeds: almonds, walnuts, chia, flax (a small handful)
# - Dairy or fortified alternatives: yogurt/kefir, cheese, fortified plant milks
# - Healthy fats: olive oil, avocado
# - Fermented foods (optional daily): yogurt/kefir, sauerkraut, kimchi
# - Hydration: water (limit sugary drinks)
#
# Quick daily plan (example):
# - Breakfast: oats with berries and yogurt
# - Lunch: big salad with greens, chickpeas, olive oil + lemon
# - Snack: apple with a handful of nuts
# - Dinner: grilled salmon or lentil curry with quinoa and vegetables
#
# Tips:
# - Fill half your plate with vegetables, a quarter with lean/protein and/or plant-based protein, a quarter with whole grains.
# - Limit added sugars, refined grains, and highly processed foods.
# - If you have allergies or medical conditions, adjust accordingly or consult a nutritionist (and vegans may need fortified foods for B12, D, iron, etc.).
#
# --------------------------------------------------
#
# Citrus-Quinoa Salmon Power Bowl
#
# Servings: 4
# Total time: about 40 minutes
#
# Ingredients
# - 1 cup dry quinoa, rinsed
# - 2 cups water or broth
# - 4 salmon fillets (about 6 oz each) or 2 cups cooked chickpeas (vegan option)
# - 2 cups broccoli florets
# - 1 large red bell pepper, sliced
# - 1 cup cherry tomatoes (optional)
# - 3–4 tbsp olive oil, divided
# - Salt and pepper to taste
# - 1 tsp paprika (or more, to taste)
# - 1/2 tsp garlic powder
# - 1 lemon (zest and juice)
# - 1 avocado, sliced
# - 1/4 cup almonds or walnuts, chopped
# - 1/2 cup plain yogurt (Greek yogurt works) + 2 tbsp tahini (optional)
# - 1 clove garlic, minced
# - Fresh parsley or dill, chopped (optional)
# - Optional: feta cheese, crumbled
#
# Dressing (yogurt-tahini)
# - 1 cup yogurt
# - 2 tbsp tahini (optional)
# - 1–2 tbsp lemon juice
# - 1 clove garlic, minced
# - Salt to taste
# - Water to reach pourable consistency
#
# Instructions
# 1) Preheat oven to 400°F (200°C). Rinse quinoa; simmer in 2 cups water/broth until fluffy (about 15 minutes). Keep warm.
# 2) Toss broccoli and bell pepper with 1–2 tbsp olive oil, salt, pepper, paprika, and garlic powder. If using chickpeas, toss them with a pinch of salt and olive oil.
# 3) Season salmon with salt, pepper, and a little paprika. Place salmon on a lined baking sheet. Roast salmon 12–15 minutes, until done. On a second sheet (or same sheet if space allows), roast veggies 12–15 minutes, until tender.
# 4) Make dressing: whisk yogurt, tahini (if using), lemon juice, garlic, and a pinch of salt. Thin with a splash of water to desired consistency.
# 5) Assemble bowls: spoon quinoa as base, top with roasted veggies, salmon (or chickpeas), avocado slices, and nuts. Drizzle with yogurt dressing. Garnish with lemon zest and herbs; sprinkle feta if desired.
#
# Tips and substitutions
# - For vegan: skip salmon; use extra chickpeas or roasted tempeh, and use dairy-free yogurt.
# - Add a citrusy finish with extra lemon juice at the table.
# - If you’re short on time, cook quinoa in advance and reheat; roast veggies and salmon overlap can reduce total time.
#
# --------------------------------------------------
#
# Rough estimates for 1 serving (the recipe makes 4 servings). Exact values vary by brand and exact amounts you use.
#
# - With salmon and tahini in dressing: about 800 kcal per serving.
# - With salmon but no tahini: about 750 kcal per serving.
# - Vegan (chickpeas instead of salmon) with tahini: about 560 kcal per serving.
# - Vegan with chickpeas, no tahini: about 520 kcal per serving.
#
# Bottom line: roughly 520–800 kcal per serving depending on protein and dressing choice. If you share the exact amounts you plan to use, I can recalc precisely.

# %% [markdown]
# ### Looping

# %%
from openai import OpenAI
import time 

client = OpenAI()

questions = list()
bot_responses = list()
messages = list()

system_prompt = input('System prompt: ')
if system_prompt == '':
    system_prompt = 'Answer as concisely as possible. '

messages.append({"role": "system", "content": system_prompt})
while True:  
    current_question = input('Me: ')
    
    if current_question.lower() in ['exit', 'quit', 'bye']:
        print('Chat Bot: I was happy to asssist you. Bye bye!')
        time.sleep(2)
        break
        
    if current_question.lower() == '':
        continue
        
    messages.append({"role": "user", "content": current_question})
    questions.append(current_question)
  
        
    completion = client.chat.completions.create(
        model="gpt-5-nano",
        messages=messages,
        temperature=1
#         max_tokens = 3000
    )
   
    current_response = completion.choices[0].message.content
    print(f'\nChat Bot: {current_response}')
    bot_responses.append(current_response)

    messages.append({"role": "assistant", "content": current_response})
    
    print('\n' + '-' * 50 + '\n')

# For debugging purposes:
# print()
# print(dict(zip(questions, bot_responses)))
# print()
# print(messages)
