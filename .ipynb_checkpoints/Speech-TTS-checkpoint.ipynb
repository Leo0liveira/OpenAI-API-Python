# %% [markdown]
# ### Transciptions with Whisper

# %%
import os 
import openai

from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv(), override=True)
openai.api_key = os.getenv('OPENAI_API_KEY')

from openai import OpenAI
client = OpenAI()

# %%
file = 'soad.mp3'
with open(file, 'rb') as audio_file:
    transcript = client.audio.transcriptions.create(
        model='whisper-1',
        file=audio_file
    )
    print(transcript)
# Out:
# Transcription(text='FALL INTO YOUR HANDS, I COMMAND MY SPIRIT, FALL INTO YOUR HANDS, WHY HAVE YOU FORSAKEN ME? IN YOUR EYES, FORSAKEN ME, IN YOUR THOUGHTS, FORSAKEN ME, IN YOUR HEART, FORSAKEN ME ALL TRUST IN MY SELF-RIGHTEOUS SUICIDE, I CRY WHEN ANGELS DESERVE TO DIE, IN MY SELF-RIGHTEOUS SUICIDE I CRY WHEN ANGELS DESERVE TO DIE', logprobs=None, usage=UsageDuration(seconds=57.0, type='duration'))

# %%
print(transcript.text)
# Out:
# FALL INTO YOUR HANDS, I COMMAND MY SPIRIT, FALL INTO YOUR HANDS, WHY HAVE YOU FORSAKEN ME? IN YOUR EYES, FORSAKEN ME, IN YOUR THOUGHTS, FORSAKEN ME, IN YOUR HEART, FORSAKEN ME ALL TRUST IN MY SELF-RIGHTEOUS SUICIDE, I CRY WHEN ANGELS DESERVE TO DIE, IN MY SELF-RIGHTEOUS SUICIDE I CRY WHEN ANGELS DESERVE TO DIE

# %% [markdown]
# ### Translations with Whisper

# %%
from openai import OpenAI
client = OpenAI()

with open('german.mp3', 'rb') as audio_file:
    translation = client.audio.translations.create(
        model='whisper-1',
        file=audio_file,
    )

print(translation)
# Out:
# Translation(text="Hello? Great, dad! It's really great here with the lions. Only this lion here, your BQ, is not here. He's probably sleeping inside, isn't he? Not today. Because today the lion is not inside, but... ...not here at all. But? At the doctor. Once a year he is examined, vaccinated, something like that. I understand. But now tell me, how was it at school? Good. The patch on your forehead, where did it come from? At the school yard. Doesn't matter. Really, dad, doesn't matter. No, it doesn't matter. They said things about you.")

# %%
from openai import OpenAI
client = OpenAI()

with open('soul.mp3', 'rb') as audio_file:
    translation = client.audio.translations.create(
        model='whisper-1',
        file=audio_file,
    )

print(translation)
# Out:
# Translation(text='健全なる 魂は 健全なる 精神と 健全なる 肉体に宿る')

# %%
print(translation.text)
# Out:
# Hello? Great, dad! It's really great here with the lions. Only this lion here, your BQ, is not here. He's probably sleeping inside, isn't he? Not today. Because today the lion is not inside, but... ...not here at all. But? At the doctor. Once a year he is examined, vaccinated, something like that. I understand. But now tell me, how was it at school? Good. The patch on your forehead, where did it come from? At the school yard. Doesn't matter. Really, dad, doesn't matter. No, it doesn't matter. They said things about you.

# %% [markdown]
# ### Text to Speech API

# %%
# text = 'Viitorul este o carte deschisă, plină de capitole încă nescrise,\
# așteptând strălucirea minților noastre să picteze poveștile lor.'

text = 'it began with the forging of the Great Rings. Three were given to the Elves, immortal, wisest and fairest of all beings. Seven to the Dwarf-Lords, great miners and craftsmen of the mountain halls. And nine, nine rings were gifted to the race of Men, who above all else desire power. For within these rings was bound the strength and the will to govern each race. But they were all of them deceived, for another ring was made. Deep in the land of Mordor, in the Fires of Mount Doom, the Dark Lord Sauron forged a master ring, and into this ring he poured his cruelty, his malice and his will to dominate all life. One ring to rule them all.'

# %%
cost = len(text)/1000 * 0.15  # cost in cents
cost
# Out:
# 0.09585

# %%
from openai import OpenAI
client = OpenAI()
response = client.audio.speech.create(
     model="gpt-4o-mini-tts", 
     voice="coral",  
     input=text
)

with open('tts-1.mp3', 'wb') as f:
    f.write(response.content)

# %%
import IPython
IPython.display.Audio('tts-1.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
