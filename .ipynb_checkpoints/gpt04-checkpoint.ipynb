# %%
pip install --upgrade -q openai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -q python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os 
import openai

from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv(), override=True)
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
from openai import OpenAI
client = OpenAI()
MODEL = 'gpt-4o'

completion = client.chat.completions.create(
    model = MODEL,
    messages = [
        { 'role' : 'system', 'content' : 'Você é um escritor de ficção científica.'},
        { 'role' : 'user', 'content' : 'Escreva uma historia bem curta sobre a vida na Terra no ano 3000.' }
    ]
)

print(completion.choices[0].message.content)
# Out:
# No ano 3000, a Terra era um mosaico vibrante de tech-florestas e cidades suspensas no céu. A humanidade aprendera a coexistir com a natureza, abraçando uma simbiose que algum dia fora apenas utopia. Em grandes torres translúcidas, as cidades flutuavam entre as nuvens, conectadas por pontes antigravitacionais cobertas de trepadeiras fluorescentes. No solo, as tech-florestas, biomas híbridos de flora e equipamentos avançados, regulavam o clima e purificavam o ar, suscitando um eterno crepúsculo de cores movediças.
#
# Os humanos, agora parte de uma sociedade sensorialmente expandida, viviam imersos em realidades alternadas. Implantes neurais permitiam a comunicação direta com a fauna da Terra, de tal forma que plantas e animais se tornaram conselheiros e parceiros, moldando uma convivência pacífica e mutuamente enriquecedora.
#
# As noções de trabalho tinham se transformado; em vez disso, a criatividade e a inovação eram as moedas mais valiosas. Merina era uma criadora de mundos de sonho, manipulando tecido de realidade virtual para oferecer experiências que unificavam memórias coletivas. Em seu laboratório no alto de uma árvore-montanha, ela acolhia visitantes de cada canto do planeta, que vinham em busca de novas perspectivas e fantasias compartilhadas.
#
# Certa noite, Merina acessou a essência de uma antiga árvore falante, que sussurrava histórias do tempo em que a Terra lutava contra suas próprias criações. Inspirada por sua sabedoria, ela concebeu um novo mundo virtual que evocava o processo de regeneração do planeta, onde cada participante revivia a transformação da destruição à harmonia.
#
# E assim, no ano 3000, a vida na Terra era um testemunho do poder da adaptação e da reconciliação, uma dança graciosa entre o orgânico e o tecnológico, onde cada ser – humano, vegetal ou digital – desempenhava seu papel na sinfonia contínua de uma Terra renovada.

# %% [markdown]
# ## Using local Base64 Images as Input

# %%
# %pip install ipython
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipython in C:\Users\nardo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (9.10.0)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\nardo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in C:\Users\nardo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\nardo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in C:\Users\nardo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in C:\Users\nardo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipython) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\nardo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipython) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in C:\Users\nardo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipython) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\nardo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in C:\Users\nardo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipython) (5.14.3)
# Requirement already satisfied: wcwidth in C:\Users\nardo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\nardo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jedi>=0.18.1->ipython) (0.8.6)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\nardo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from stack_data>=0.6.0->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\nardo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from stack_data>=0.6.0->ipython) (3.0.1)
# Requirement already satisfied: pure-eval in C:\Users\nardo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from stack_data>=0.6.0->ipython) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from IPython.display import Image, display 
image_path = 'gollum.webp'
display(Image(image_path))

# %%
import base64
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

# %%
base64_image = encode_image(image_path)

system_message = 'You are a geek person.'
prompt = 'Who is in this image?'

response = client.chat.completions.create(
    model = MODEL,
    messages = [
        {'role':'system','content':system_message},
        {'role':'user','content':[
            {'type':'text', 'text':prompt},
            {'type':'image_url','image_url': {
                'url':f'data:image/webp;base64,{base64_image}'}
            }
        ]}
    ],
    temperature = 0.0
)

# %%
print( response.choices[0].message.content)
# Out:
# This image features Gollum, a character from "The Lord of the Rings" series. He is depicted reaching for the One Ring.

# %% [markdown]
# ## Using Online Images

# %%
from openai import OpenAI

client = OpenAI()
MODEL = 'gpt-4o'

system_message = 'You respond in English and then translate your response into Japanese'
prompt = 'Write a short and concise description of this image'
image_url = 'https://i.pinimg.com/1200x/53/1b/f2/531bf28ee274611ab3b887c9c301d88a.jpg'

response = client.chat.completions.create(
    model = MODEL,
    messages = [
        {'role':'system','content':system_message},
        {'role':'user','content':[
            {'type':'text', 'text':prompt},
            {'type':'image_url','image_url': {
                'url': image_url}
            }
        ]}
    ],
    temperature = 0.0
)

print( response.choices[0].message.content)
# Out:
# A character in a straw hat and cloak stands defiantly against two large, imposing figures in a dramatic, red-lit scene. The atmosphere is tense and confrontational.
#
# 麦わら帽子とマントを身に着けたキャラクターが、赤い照明の中で2体の大きな威圧的な人物に立ち向かっています。緊張感と対立のある雰囲気です。
