# %%
print ('Hello from Jupyter!')
x = 10
x

# %%
print (x - 2)

# %% [markdown]
# # Python Lists
# ## Methods
#
# **This is an example of bold *and italic* text**
#
# `append()` is a list method.
#
# Python methods:
# - append()
# - insert()
# - pop()

# %%
x = 100

# %%
print (x*2)

# %%
import time
time.sleep(3)
print(5)
