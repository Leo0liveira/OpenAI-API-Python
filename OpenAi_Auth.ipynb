# %%
# !pip install -q openai
import openai
import os

# %%
# os.environ['x'] = 'abc'
# os.getenv('x')

# os.environ['OPENAI_API_KEY'] = 'your_api_key'
# openai.api_key = os.getenv('OPENAI_API_KEY')

# import getpass
# key = getpass.getpass('Paste your API KEY:')
# openai.api_key = key

# openai.api_key = open('key.txt').read().strip('\n')

# %% [markdown]
# ### Making GFT Requests Using the OpenAI API

# %%
# !pip show openai
# Out:
# Name: openai
# Version: 2.20.0
# Summary: The official Python library for the openai API
# Home-page: https://github.com/openai/openai-python
# Author:
# Author-email: OpenAI <support@openai.com>
# License: Apache-2.0
# Location: C:\Users\nardo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages
# Requires: anyio, distro, httpx, jiter, pydantic, sniffio, tqdm, typing-extensions
# Required-by:

# %%
# !pip install --upgrade openai -q

# %%
import os
os.environ['OPENAI_API_KEY'] = 'YOUR_API_SECRET'
os.getenv('OPEN_API_KEY')

# %%
from  openai import OpenAI
client = OpenAI()
# for model in client.models.list():
#     print(model)

response = client.chat.completions.create(
    model='gpt-3.5-turbo', 
    messages=[
        {'role':'system','content':'Você é um assistente prestativo.'},
        {'role':'user','content':'O que é a equação de campo de Einstein?'}
    ]
)

#roles => system -> user -> assistant
print(response)
# Out:
# ChatCompletion(id='chatcmpl-D89SOUNnh3hakqUYo65At6XwLlHbt', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='A equação de campo de Einstein é a formulação matemática fundamental da teoria da relatividade geral, proposta por Albert Einstein em 1915. Essa equação descreve como a matéria e a energia produzem curvatura no espaço-tempo, que por sua vez influencia o movimento dos corpos celestes. A equação de campo de Einstein é composta por tensores que representam a geometria do espaço-tempo e a distribuição de matéria e energia. Ela é fundamental para compreender a gravitação e fenômenos astrofísicos como buracos negros, ondas gravitacionais e a expansão do universo.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1770835348, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=148, prompt_tokens=31, total_tokens=179, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
