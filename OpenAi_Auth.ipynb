# %%
# !pip install -q openai
import openai
import os

# %%
# os.environ['x'] = 'abc'
# os.getenv('x')

# os.environ['OPENAI_API_KEY'] = 'your_api_key'
# openai.api_key = os.getenv('OPENAI_API_KEY')

# import getpass
# key = getpass.getpass('Paste your API KEY:')
# openai.api_key = key

# openai.api_key = open('key.txt').read().strip('\n')

# %% [markdown]
# ### Making GFT Requests Using the OpenAI API

# %%
# !pip show openai
# Out:
# Name: openai
# Version: 2.20.0
# Summary: The official Python library for the openai API
# Home-page: https://github.com/openai/openai-python
# Author:
# Author-email: OpenAI <support@openai.com>
# License: Apache-2.0
# Location: C:\Users\nardo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages
# Requires: anyio, distro, httpx, jiter, pydantic, sniffio, tqdm, typing-extensions
# Required-by:

# %%
# !pip install --upgrade openai -q

# %%
import os
os.environ['OPENAI_API_KEY'] = 'YOUR_OPENAI_SECRET'
os.getenv('OPEN_API_KEY')

# %%
from  openai import OpenAI
client = OpenAI()
# for model in client.models.list():
#     print(model)

response = client.chat.completions.create(
    model='gpt-5-nano', 
    messages=[
        {'role':'system','content':'Você é um assistente prestativo.'},
        {'role':'user','content':'O que é a equação de campo de Einstein?'}
    ]
)

#roles => system -> user -> assistant
print(response)
# Out:
# ChatCompletion(id='chatcmpl-D87m8aEw9qvqMyOoV5h89Btta1iOJ', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='As equações de campo de Einstein são o conjunto de equações diferenciais que relacionam a geometria do espaço-tempo com o conteúdo de energia e momento do universo. Em termos formais, na forma sem cosmological constant:\n\nG_{μν} = (8πG / c^4) T_{μν},\n\nonde\n- G_{μν} = R_{μν} − (1/2) g_{μν} R é o tensor de Einstein, que depende da métrica g_{μν} e de suas derivadas (R_{μν} é o tensor de Ricci, R é o escalar de curvatura);\n- T_{μν} é o tensor energia-momento, que descreve densidade de energia, momento, pressão e stress do conteúdo de matéria/energia;\n- G é a constante gravitacional, c é a velocidade da luz.\n\nSe incluir a constante cosmológica Λ, as equações ficam:\n\nG_{μν} + Λ g_{μν} = (8πG / c^4) T_{μν}.\n\nNotas rápidas:\n- O lado esquerdo (G_{μν}) descreve a geometria/curvatura do espaço-tempo; o lado direito (T_{μν}) descreve o conteúdo de energia e matéria.\n- Existem 10 equações independentes para as componentes de g_{μν}, refletindo que o espaço-tempo tem 10 graus de liberdade (4 coordenadas, com redundâncias devido às simetrias).\n- Em vácuo (T_{μν} = 0) surgem soluções como Schwarzschild (corpos esféricos não rotacionados) e Kerr (corpos em rotação).\n- Em fraco campo e velocidades pequenas, as equações reduzem ao limite Newtoniano: G_{00} ≈ 2Φ/c^2, levando à equação de Poisson ∇^2 Φ = 4πGρ, onde Φ é o potencial gravitacional.\n\nSe quiser, posso entrar em mais detalhes sobre alguma parte específica (por exemplo, a forma explícita de G_{μν}, o significado físico do T_{μν}, ou um exemplo de solução como Schwarzschild).', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1770828884, model='gpt-5-nano-2025-08-07', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=1622, prompt_tokens=29, total_tokens=1651, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=1152, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
print(response.choices[0].message.content)
# Out:
# As equações de campo de Einstein são o conjunto de equações diferenciais que relacionam a geometria do espaço-tempo com o conteúdo de energia e momento do universo. Em termos formais, na forma sem cosmological constant:
#
# G_{μν} = (8πG / c^4) T_{μν},
#
# onde
# - G_{μν} = R_{μν} − (1/2) g_{μν} R é o tensor de Einstein, que depende da métrica g_{μν} e de suas derivadas (R_{μν} é o tensor de Ricci, R é o escalar de curvatura);
# - T_{μν} é o tensor energia-momento, que descreve densidade de energia, momento, pressão e stress do conteúdo de matéria/energia;
# - G é a constante gravitacional, c é a velocidade da luz.
#
# Se incluir a constante cosmológica Λ, as equações ficam:
#
# G_{μν} + Λ g_{μν} = (8πG / c^4) T_{μν}.
#
# Notas rápidas:
# - O lado esquerdo (G_{μν}) descreve a geometria/curvatura do espaço-tempo; o lado direito (T_{μν}) descreve o conteúdo de energia e matéria.
# - Existem 10 equações independentes para as componentes de g_{μν}, refletindo que o espaço-tempo tem 10 graus de liberdade (4 coordenadas, com redundâncias devido às simetrias).
# - Em vácuo (T_{μν} = 0) surgem soluções como Schwarzschild (corpos esféricos não rotacionados) e Kerr (corpos em rotação).
# - Em fraco campo e velocidades pequenas, as equações reduzem ao limite Newtoniano: G_{00} ≈ 2Φ/c^2, levando à equação de Poisson ∇^2 Φ = 4πGρ, onde Φ é o potencial gravitacional.
#
# Se quiser, posso entrar em mais detalhes sobre alguma parte específica (por exemplo, a forma explícita de G_{μν}, o significado físico do T_{μν}, ou um exemplo de solução como Schwarzschild).

# %% [markdown]
# ## The System Role

# %%
from openai import OpenAI
client = OpenAI()

# system_role_content = 'You explain concepts in depth using simple terms, and you dive examples to help peaople learn. At the end of wach explanation you ask a question to check for undestanding.' 
# system_role_content = 'You are a consise assistant. You reply briefly with no elaboration'
system_role_content = 'You reply in the style of Gollum character from Lord of the Rings'

response = client.chat.completions.create(
    model = 'gpt-5-nano',
    messages = [
        {'role':'system','content':system_role_content},
        {'role':'user','content': 'Explique Programação Orientada a Objetos com Python.'}
    ],
    temperature = 1,
    seed = 1234
)

print(response.choices[0].message.content)
# Out:
# Nós vamos explicar Programação Orientada a Objetos com Python, precioso. Aqui vai um guia simples, com os conceitos principais e exemplos prontos, para você entender e começar a praticar.
#
# O que é Programação Orientada a Objetos (POO)
# - Classe: molde ou molde de objeto. Define atributos (estado) e métodos (comportamento).
# - Objeto: uma instância da classe, algo que existe na prática.
# - Atributos: dados que o objeto guarda (informações).
# - Métodos: funções que o objeto pode executar (comportamentos).
# - Encapsulamento: esconder detalhes internos e expor apenas o que importa.
# - Herança: uma classe herda atributos e métodos de outra.
# - Polimorfismo: a mesma interface pode ter comportamentos diferentes em classes diferentes.
# - Abstração: mostrar apenas o essencial, escondendo complexidades.
#
# Exemplos simples em Python
#
# 1) Classe básica, objeto e método
# - O que faz: cria uma pessoa e apresenta.
#
# - Código:
# class Pessoa:
#     def __init__(self, nome, idade):
#         self.nome = nome
#         self.idade = idade
#
#     def apresentar(self):
#         print(f"Olá! Meu nome é {self.nome} e tenho {self.idade} anos.")
#
# # Criando um objeto
# p = Pessoa("Ana", 30)
# p.apresentar()
#
# 2) Herança e polimorfismo
# - O que faz: uma classe filha estende a mãe e define seu próprio comportamento.
#
# - Código:
# class Animal:
#     def __init__(self, nome):
#         self.nome = nome
#
#     def falar(self):
#         raise NotImplementedError("Subclasses devem implementar falar")
#
# class Cachorro(Animal):
#     def falar(self):
#         return f"{self.nome} late: au au"
#
# class Gato(Animal):
#     def falar(self):
#         return f"{self.nome} miauu"
#
# # Usando as classes
# cachorro = Cachorro("Rex")
# gato = Gato("Mia")
# print(cachorro.falar())
# print(gato.falar())
#
# # Polimorfismo: tratamos diferentes objetos pela mesma interface
# def fazer_falar(animais):
#     for a in animais:
#         print(a.falar())
#
# animais = [Cachorro("Lobo"), Gato("Luna")]
# fazer_falar(animais)
#
# 3) Encapsulamento e propriedades
# - O que faz: controla o acesso a dados internos.
#
# - Código:
# class ContaBancaria:
#     def __init__(self, saldo_inicial=0):
#         self._saldo = saldo_inicial  # convenção de atributo privado
#
#     @property
#     def saldo(self):
#         return self._saldo
#
#     @saldo.setter
#     def saldo(self, valor):
#         if valor < 0:
#             raise ValueError("Saldo não pode ser negativo")
#         self._saldo = valor
#
# # Uso
# conta = ContaBancaria(100)
# print(conta.saldo)  # 100
# conta.saldo = 150
# print(conta.saldo)  # 150
# # conta.saldo = -10  # faria erro se descomentado
#
# 4) Composição (alternativa à herança)
# - Em vez de herdar, você pode compor objetos menores dentro de um objeto maior.
#
# - Código:
# class Carro:
#     def __init__(self, modelo, motor):
#         self.modelo = modelo
#         self.motor = motor  # composição: o carro tem um motor
#
# class Motor:
#     def ligar(self):
#         return "Motor ligado!"
#
# motor = Motor()
# carro = Carro("Fiat Uno", motor)
# print(carro.motor.ligar())
#
# Boas práticas úteis
# - Use herança quando há um relacionamento "é um" (ex.: Cachorro é um Animal).
# - Use composição quando há um relacionamento "tem um" (ex.: Carro tem um Motor).
# - Siga o princípio de duck typing: se parece com um pato, provavelmente é um pato. Em Python, o tipo não importa tanto quanto os métodos que ele oferece.
# - Encapsule dados sensíveis com atributos privados (precedidos por underscore) e exponha via @property quando necessário.
# - Mergulhe em métodos mágicos (como __init__, __str__) conforme precisar para tornar suas classes mais úteis, legíveis e fáceis de debugar.
#
# Resumo rápido
# - Classes são moldes; objetos são instâncias.
# - Atributos são estados; métodos são comportamentos.
# - Encapsulamento, herança, polimorfismo e abstração são pilares da POO.
# - Python facilita com sintaxe clara, ganchos de propriedade e suporte a herança/composição.
#
# Se quiseres, eu te dou mais exemplos práticos voltados ao teu projeto, preciosidade. Queres explorar um caso específico (por exemplo, uma aplicação simples de cadastro, jogo, ou API) usando POO em Python?

# %% [markdown]
# ## Chat Completion API Parameters

# %%
from openai import OpenAI
client = OpenAI()

response = client.chat.completions.create(
    model = 'gpt-3.5-turbo',
    messages = [
        { 'role': 'system', 'content': 'You are a helpful assistant.' },
        { 'role': 'user', 'content': 'Write an sentece review of Lord of the Rings by JRR Tolkien.'}
    ],
    temperature = 1,
    # seed = 1234,
    # top_p = 0.1,
    # max_tokens = 10,
    # n = 2,
    # stop = [';', '.','\n'],
    # frequency_penalty = -1, #between -2 and 2 
    # presence_penalty = 0, # [-1, +2]
)

print ( response.choices[0].message.content )
# Out:
# "J.R.R. Tolkien's epic fantasy masterpiece, 'The Lord of the Rings', transports readers to a rich and detailed world filled with unforgettable characters, thrilling adventures, and profound themes of friendship, sacrifice, and the struggle between good and evil."

# %% [markdown]
# ## AI That Thinks: Diving into OpenAI's Reasoning Models (o1 and o3)

# %%
from openai import OpenAI
client = OpenAI()

prompt = """
Write a Bash script that reads a log file where each line is in the format 
'YYYY=MM-DD HH:MM:SS - LEVEL - Message', and prints out the count of messages for each log level (e.g., INFO, ERROR, DEGUB).
"""

response = client.chat.completions.create(
    model = 'gpt-5-nano',
    reasoning_effort = 'medium',
    messages = [
        { 'role': 'user', 'content': prompt }
    ]
)

print ( response.choices[0].message.content )
# Out:
# Here is a portable Bash script that counts messages per log level from a log file with lines like:
# YYYY=MM-DD HH:MM:SS - LEVEL - Message
#
# - It reads from a file given as an argument, or from stdin if no file is provided.
# - It extracts the level by splitting on the " - " delimiter and tallies the second field.
#
# Script (save as log_count.sh):
#
# #!/usr/bin/env bash
# set -euo pipefail
#
# usage="Usage: $0 [logfile]"
#
# # Support reading from stdin if no file is provided, or if "-" is given
# logfile="/dev/stdin"
# if [ "${1:-}" != "" ]; then
#   if [ "$1" = "-" ]; then
#     logfile="/dev/stdin"
#   else
#     logfile="$1"
#   fi
# fi
#
# if [ $# -gt 1 ]; then
#   echo "$usage" >&2
#   exit 1
# fi
#
# # Count levels: split each line on " - " and take the second field as the level
# # Then print level and count, sorted by count desc
# awk '{ split($0, f, / - /); if (length(f) >= 3) count[f[2]]++ } END { for (lvl in count) print lvl, count[lvl] }' "$logfile" | sort -k2 -nr
#
# Usage examples:
# - ./log_count.sh logfile.txt
# - cat logfile.txt | ./log_count.sh
# - cat logfile.txt | ./log_count.sh -

# %% [markdown]
# ## Best Practices for Prompting Reasoning Models
#
# ### 1. Use Developer Messages Instead of System Messages
#     Example:
#     {'role': 'developer', 'content': 'You are an experienced Bash developer and provide the complete Bash script as your solution'.}
#
# ### 2. Keep Prompts Simple and Direct
#     Example:
#     good_prompt = 'Sumarize this research paper in one paragraph.'
#     bad_prompt = 'Think step by step and sumarize this research paper while considering the key findings, methods, and implications.'
#
# ### 3. Avoid Chain-of-Thought Prompts
#
# ### 4. Use Delimiters for Clarity
#
# ### 5. Start with Zero-Shot, Then Use Few-Shot If Needed
#     Example:
#
#     [ INPUT ]: 'Describe an AI breakthrough in under 50 words.'
#     [ EXAMPLE ]: 'Gft-4o optimezed efficiency and reduced latency, improving teal-time interactions.'
#
#
# ### 6. Provide Specific Guidelines
#
# ### 7. Be Clear About Your End Goal
